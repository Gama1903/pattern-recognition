# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y1 = x
y2 = x**2
y3 = x**(1 / 2)

color = '#EBEBEB'
fig = plt.figure(num=1, facecolor=color)
ax = plt.subplot(facecolor=color)

plt.grid(True, color='#F8F8F8')

plt.figure(num=2, facecolor=color)
plt.plot()

plt.grid(True, color='#F8F8F8')
# Out:
# D:\Temp\ipykernel_27600\350472822.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y3 = x**(1 / 2)
